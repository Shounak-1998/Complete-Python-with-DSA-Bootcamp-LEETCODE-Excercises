# %%
a = 10
b = 5

add_result = a + b
sub_result = a - b
mul_result = a * b
div_result = a / b
floor_div_result = a // b
modulus_result = a % b
exponent_result = a**b

print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21 // 5
# Out:
# 4

# %%
21 % 5
# Out:
# 1

# %%
21**5
# Out:
# 4084101

# %%
#### Comparison Operator
a = 100
b = 5

a == b
# Out:
# False

# %%
str1 ="Shounak"
str2 = "Shounak"

str1==str2
# Out:
# True

# %%
# Not Equal to

str1!=str2
# Out:
# False

# %%
# Greater than
num1 = 45
num2 = 55

num1>num2
# Out:
# False

# %%
# Less than

num1<num2
# Out:
# True

# %%
#greater than or equal to
number1=45
number2=45

number1>=number2
# Out:
# True

# %%
#less than or equal to
number1=45
number2=45

number1<=number2
# Out:
# True

# %%
#### Logical Operator
#AND, NOT, OR
X=True
Y=False

result = X and Y
print(result)
# Out:
# False

# %%
#Part 1: Arithmetic Operators

#Predict the output:

print(10 + 5) #15
print(10 - 5) #5
print(10 * 5) #50
print(10 / 5) #2.0
print(10 % 3) #1
print(10 // 3) #3
print(2 ** 4) #16
# Out:
# 15
# 5
# 50
# 2.0
# 1
# 3
# 16

# %%
#Part 2: Calculate the Result

#Find the value of:

print(15 + 20) # 35
print(50 - 18) # 32
print(12 * 6) #72
print(100 / 4) #25.0
print(17 % 5) #2
print(17 // 5) #3
print(3 ** 3) #27
# Out:
# 35
# 32
# 72
# 25.0
# 2
# 3
# 27

# %%
#Part 3: Assignment Operators

#What will be the value of x after each operation?

x = 10 #10
print(x)
x += 5
print(x)#15
x = 20 #20
print(x)
x -= 8 #12
print(x)
x = 6 #6
print(x)
x *= 4 #24
print(x)
x = 24 #24
print(x)
x /= 6 #4.0
print(x)
x = 10 #10
print(x)
x %= 3 #1
print(x)
# Out:
# 10
# 15
# 20
# 12
# 6
# 24
# 24
# 4.0
# 10
# 1

# %%
#Part 4: Comparison Operators

#Predict whether the result is True or False.

10 == 10 #True
10 != 5 #True
7 > 9 # False
15 < 20 #True
8 >= 8 #True
5 <= 3 #False
# Out:
# False

# %%
numbers = [10, 20, 30, 40]

#Predict the output:

20 in numbers
# Out:
# True

# %%
a = [1, 2]
b = a

print(a is b)
# Out:
# True

# %%
#Part 10: Mini Programs
#Find the area of a rectangle using length and width.
num1 = float(input("Enter the Length: "))
num2 = float(input("Enter the Width: "))
area_of_rectangle = num1*num2
print("Area of a rectangle :",area_of_rectangle)
#Find the remainder when 27 is divided by 4.
number1 = 27 % 4
print(number1)
#Check whether a number is greater than 100.
no = float(input("Enter the number to check if its grater than 100 :"))
greater = no > 100
print(greater)
#Check if a person is eligible to vote (age ≥ 18).
age = float(input("Enter the number to check eligible to vote above than 18 :"))
eligible = age >= 18
print(eligible)
#Check whether a number exists in a list.
#Calculate the square of a number using an operator.
num1 = float(input("Enter the number: "))
print(num1**2)
#Calculate the cube of a number using an operator.
num1 = float(input("Enter the number: "))
print(num1**3)
# Out:
# Enter the Length: 45
# Enter the Width: 2
# Area of a rectangle : 90.0
# 3
# Enter the number to check if its grater than 100 :105
# True
# Enter the number to check eligible to vote above than 18 :20
# True
# Enter the number: 8
# 64.0
# Enter the number: 10
# 1000.0
